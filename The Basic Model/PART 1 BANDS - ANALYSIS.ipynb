# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

file_data = '/Users/cemalarican/Desktop/THESIS/PART 1/BANDS/'
file_main_data = '/Users/cemalarican/Desktop/THESIS/PART 1/BANDS/MAIN_DATA_BANDS/'

bands = [0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]

# before the swap: stock1 actually equals stock2
coint_pairs = pd.read_csv('/Users/cemalarican/Desktop/THESIS/pairs_to_investigate.csv')

import sys  
sys.path.insert(0, '/Users/cemalarican/Desktop/THESIS/')

from pipeLine import Pipeline

# %%
data = pd.DataFrame()

for band in bands:
    data['perf_' + str(band)] = pd.read_csv(file_data + 'pair_sim_band_' + str(band)+'.csv').iloc[-1]

data.drop('Unnamed: 0', inplace=True)
print(len(data))
idx = list(data.index)

for band in bands:
    d =  pd.read_csv(file_data + 'MAIN_DATA_BANDS/pair_sim_band_'+ str(band) +'.csv').groupby('symbol')
    alphas = []
    betas = []
    sharpes = []
    maxes = []
    for i in range(239):
        
        stock_alpha = d.get_group(idx[i]).alpha.iloc[-1]
        stock_beta = d.get_group(idx[i]).beta.iloc[-1]
        stock_sharpe = d.get_group(idx[i]).sharpe.iloc[-1]
        stock_max = d.get_group(idx[i]).max_drawdown.iloc[-1]
        alphas.append(stock_alpha)
        betas.append(stock_beta)
        sharpes.append(stock_sharpe)
        maxes.append(stock_max)

    data['alpha_' + str(band)] = alphas
    data['beta_' + str(band)] = betas
    data['sharpe_' + str(band)] = sharpes
    data['maxdraw_' + str(band)] = maxes


data['STAT'] = [list(data.index)[i].split(':')[1] for i in range(len(data)) ]

for band in bands:
    data['pct_'+str(band)] = (data['perf_' +str(band)]/100000) -1
    
data
# Out:
# 239
#                         perf_0.25     perf_0.5 perf_0.75   perf_1 perf_1.25  \
# MZZ vs SMDD:NON-STAT      -168936      46345.4   47253.6  35060.9    111836
# EDV vs UBT:NON-STAT       89588.2      89588.2   89588.2  87996.6   87996.6
# IVV vs IWB:STAT           92981.1      92990.3   93838.6  94921.7   93362.3
# DGL vs SGOL:STAT          91489.5       100334   99098.6  98701.2   96404.9
# PHDG vs VQT:STAT           102458      95958.2     98653    97276   96338.6
# IWV vs SCHB:NON-STAT       106430       106330    107432   107718    107987
# IWB vs SPY:STAT           93708.9      93516.3   94495.3  95974.5   94984.4
# IWB vs SSO:STAT            155385       155385    155385   155385    155285
# CURE vs RXL:STAT           -11569       -11850   87453.5  85262.4     86381
# EUSA vs VV:STAT            109682       134055    143521   166674    101806
# PHYS vs SGOL:NON-STAT     96946.2      98418.8   98718.1  98922.3   99247.9
# FXP vs YANG:NON-STAT       142328       146766    171273   171826    167201
# SCHB vs VTI:NON-STAT       104083       105345    106847   106407    105696
# DGL vs GLD:STAT            106024       105553    104922   104922    104857
# DLN vs VYM:NON-STAT       97066.4      97287.9   97711.4  97753.5   97791.3
# FUTY vs XLU:NON-STAT      96941.4      95685.8   95209.8  96545.7     95627
# FXY vs YCL:STAT            416868       626144   -144909  62387.3   61741.7
# VPU vs XLU:NON-STAT       97499.3      94744.5   97085.4  96284.5   96277.2
# GLD vs PHYS:STAT          90003.4      88732.7    100025  94168.4   87041.6
# SCHG vs VOOG:STAT         95591.5      95596.5   97225.5  98196.5   97958.7
# SCHB vs VONE:NON-STAT     98096.6      97815.1    101515   100320   98087.9
# PGF vs PGX:STAT           99102.8      99161.9   98886.2  99063.6   99063.4
# DOG vs DXD:STAT           73037.8      77748.9   78014.5  73688.2   79628.4
# SBND vs TTT:STAT          61646.8      61278.1     72057  73182.6   78743.4
# DNO vs DTO:NON-STAT        156065       168803    168803   168803    168803
# ITOT vs VOO:STAT          92511.6      91460.6     92069  93451.3   93738.2
# IWB vs SCHB:NON-STAT      96833.4      96627.4   98092.4  99951.3     98789
# SSO vs VOO:STAT            130007       130176    129902   129902    129902
# IWL vs MGC:STAT           30606.8      99465.5   93769.2  96367.4   96344.5
# TBT vs TMV:NON-STAT         88790      86234.1     83194  84641.7   81097.7
# ...                           ...          ...       ...      ...       ...
# EMES vs EMESQ:STAT         100000       100000    100000   100000    100000
# EMES vs EMESZ:STAT         100000       100000    100000   100000    100000
# PHIO vs RXII:STAT         44429.1      44429.1   44429.1  44429.1   44429.1
# PTIE vs SAVA:STAT          100000       100000    100000   100000    100000
# RAS vs RASFD:STAT          100000       100000    100000   100000    100000
# CBS vs VIAC:NON-STAT      99635.2      99643.7   99645.1  99655.2   99662.2
# CHI_2 vs QQQC:STAT        58563.8       108448    123920  88363.2    107991
# CUR vs SNCA:STAT           100000       100000    100000   100000    100000
# CWEN vs NYLD:STAT          100453       100453    100551   100546    100612
# EVLV vs IMBI:STAT      4.8877e+06  4.26273e+06    187198   187198    187727
# IPCI vs IPCIF:STAT        99873.8      99946.3   99946.3  99946.3   99946.3
# KEG vs KEGX:STAT          99853.4      99853.4   99853.4  99853.4   99853.4
# KEG vs KEGXD:STAT         99853.4      99853.4   99853.4  99853.4   99853.4
# MPVD vs MPVDF:STAT        82805.4      82805.4   82805.4  82805.4   82805.4
# PIPR vs PJC:STAT          99732.5        99636     99659  99579.7   99440.4
# SDRL vs SDRL_:STAT        -651087      -651087   -651087  -651087   -651087
# SPN vs SPNV:STAT           104522       104522    104522   104522    104522
# SPN vs SPNVD:STAT          104522       104522    104522   104522    104522
# TTS vs TTSH:STAT          97856.6      98239.2   98621.2    98993   98853.9
# ANW vs ANWWQ:STAT          100000       100000    100000   100000    100000
# ATCO vs SSW:STAT           100000       100000    100000   100000    100000
# BAS vs BASX:STAT          99956.9       100000    100000   100000    100000
# FEU vs SPEU:STAT          99638.7      99749.1   99754.7  99759.9   99772.9
# FRGA vs TAX:STAT           100000       100000    100000   100000    100000
# GOV vs OPI:STAT           88987.9      88987.9   88987.9  88987.9   91556.5
# HPT vs SVC:STAT           99165.4      99626.5     99637  99637.1   99878.8
# OZM vs SCU:NON-STAT       96286.8      96302.9     96406  96423.1   96424.8
# PXMV vs XMVM:STAT           98683      98856.4   98856.4  99084.3   99357.7
# RC vs SLD:STAT            82591.3       100982    100054   100172    100490
# TAX vs TAXA:STAT           100000       100000    100000   100000    100000
#
#                       perf_1.5 perf_1.75   perf_2  alpha_0.25  beta_0.25  \
# MZZ vs SMDD:NON-STAT    111836    200919   200919   -4.443507  -4.086121
# EDV vs UBT:NON-STAT    87996.6     87946  88114.2   -0.110140   0.033323
# IVV vs IWB:STAT        95709.4   97934.6  97787.9   -0.073904   0.089227
# DGL vs SGOL:STAT       96552.3   96096.1  98303.1   -0.080367  -0.101227
# PHDG vs VQT:STAT         96520   96850.6  98694.2    0.025774   0.033696
# IWV vs SCHB:NON-STAT    108440    102714   103040    0.067701  -0.149594
# IWB vs SPY:STAT        97396.4   99483.1  99516.7   -0.066387   0.100424
# IWB vs SSO:STAT         155286    155291   155032    0.532489   0.530698
# CURE vs RXL:STAT       88699.6   90559.5  90416.4   -1.322152   0.529132
# EUSA vs VV:STAT        86529.4   85822.8  84763.2   16.297713 -24.475282
# PHYS vs SGOL:NON-STAT  98782.8   98731.4  99527.3   -0.031094   0.008080
# FXP vs YANG:NON-STAT    172291    168256   172457    0.635014  -0.802551
# SCHB vs VTI:NON-STAT    106111    103223   103191    0.046213  -0.204203
# DGL vs GLD:STAT         104857    106209   105877    0.059862   0.032298
# DLN vs VYM:NON-STAT    97708.5     97710  97556.2   -0.029371  -0.013404
# FUTY vs XLU:NON-STAT   95891.4   95523.2  95523.2   -0.028313  -0.079676
# FXY vs YCL:STAT        85530.6     92477  96503.9    3.733458   0.760896
# VPU vs XLU:NON-STAT    96933.3   96586.7  97259.8   -0.026144   0.090340
# GLD vs PHYS:STAT       87034.7     89269    89013   -0.099357   0.020986
# SCHG vs VOOG:STAT      98287.9   98258.1  97865.3   -0.048133   0.171460
# SCHB vs VONE:NON-STAT  98502.1    100984   101178   -0.019033   0.037096
# PGF vs PGX:STAT        98860.8     98816  98827.2   -0.008993   0.001851
# DOG vs DXD:STAT        77988.5   78552.7  75913.7   -0.303637   0.039211
# SBND vs TTT:STAT       74311.8     78570  81391.1   -0.399110  -0.479796
# DNO vs DTO:NON-STAT     140063    128028   132121    0.490731   0.304766
# ITOT vs VOO:STAT       93425.1   95730.1  97895.4   -0.066551  -0.322624
# IWB vs SCHB:NON-STAT   98958.9   98263.5  98447.6   -0.034294   0.156969
# SSO vs VOO:STAT         131152    131152   131152    0.326933   0.099401
# IWL vs MGC:STAT          95699     97085  97094.5  -34.856750 -14.920650
# TBT vs TMV:NON-STAT    81841.9   85087.4  83601.7   -0.112323  -0.016574
# ...                        ...       ...      ...         ...        ...
# EMES vs EMESQ:STAT      100000    100000   100000    0.000000   0.000000
# EMES vs EMESZ:STAT      100000    100000   100000    0.000000   0.000000
# PHIO vs RXII:STAT      48584.6     52032  88848.1   -0.660398   0.072540
# PTIE vs SAVA:STAT       100000    100000   100000    0.000000   0.000000
# RAS vs RASFD:STAT       100000    100000   100000    0.000000   0.000000
# CBS vs VIAC:NON-STAT   99877.5   99881.6  99889.6   -0.003661   0.000330
# CHI_2 vs QQQC:STAT     93440.4    103795  92559.6   -0.247561   2.439658
# CUR vs SNCA:STAT        100000    100000   100000    0.000000   0.000000
# CWEN vs NYLD:STAT       100502    100630  98495.1    0.004367   0.021510
# EVLV vs IMBI:STAT      45668.3   45668.3  45668.3   49.291894 -10.866722
# IPCI vs IPCIF:STAT     99946.3   99946.3  99946.3   -0.001260  -0.000103
# KEG vs KEGX:STAT       99853.4   99853.4  99853.4   -0.001454  -0.000537
# KEG vs KEGXD:STAT      99853.4   99853.4  99853.4   -0.001454  -0.000537
# MPVD vs MPVDF:STAT     82805.4   77825.8   112183   -0.156226  -0.081151
# PIPR vs PJC:STAT       99916.1   99799.2  99621.6   -0.002453  -0.008472
# SDRL vs SDRL_:STAT     -651087   -651087  -651087   32.581398   7.451868
# SPN vs SPNV:STAT        104522    104522   104522    0.164583  -1.145297
# SPN vs SPNVD:STAT       104522    104522   104522    0.164583  -1.145297
# TTS vs TTSH:STAT       98670.5   98418.7   100000   -0.021776   0.006700
# ANW vs ANWWQ:STAT       100000    100000   100000    0.000000   0.000000
# ATCO vs SSW:STAT        100000    100000   100000    0.000000   0.000000
# BAS vs BASX:STAT        100000    100000   100000   -0.000439   0.000330
# FEU vs SPEU:STAT       99777.3   99779.9  99789.9   -0.003614  -0.000180
# FRGA vs TAX:STAT        100000    100000   100000    0.000000   0.000000
# GOV vs OPI:STAT          91470     91470    91470   -0.118357   0.337054
# HPT vs SVC:STAT        99893.1   99900.1  99907.8   -0.008387   0.000439
# OZM vs SCU:NON-STAT    96417.7     96611  96613.7   -0.037805  -0.000982
# PXMV vs XMVM:STAT      99913.3   99909.1  99909.1   -0.013913   0.031436
# RC vs SLD:STAT          100523    100821   100476   -0.160746  -0.171423
# TAX vs TAXA:STAT        100000    100000   100000    0.000000   0.000000
#
#                           ...       maxdraw_2      STAT     pct_0.25  \
# MZZ vs SMDD:NON-STAT      ...       -2.307025  NON-STAT     -2.68936
# EDV vs UBT:NON-STAT       ...       -0.131181  NON-STAT    -0.104118
# IVV vs IWB:STAT           ...       -0.043298      STAT   -0.0701892
# DGL vs SGOL:STAT          ...       -0.051665      STAT   -0.0851054
# PHDG vs VQT:STAT          ...       -0.060178      STAT    0.0245775
# IWV vs SCHB:NON-STAT      ...       -0.022840  NON-STAT    0.0643029
# IWB vs SPY:STAT           ...       -0.035713      STAT    -0.062911
# IWB vs SSO:STAT           ...       -0.066060      STAT     0.553848
# CURE vs RXL:STAT          ...       -0.169966      STAT     -1.11569
# EUSA vs VV:STAT           ...       -0.326517      STAT    0.0968186
# PHYS vs SGOL:NON-STAT     ...       -0.007852  NON-STAT   -0.0305379
# FXP vs YANG:NON-STAT      ...       -0.393221  NON-STAT     0.423277
# SCHB vs VTI:NON-STAT      ...       -0.012271  NON-STAT    0.0408326
# DGL vs GLD:STAT           ...       -0.031951      STAT    0.0602358
# DLN vs VYM:NON-STAT       ...       -0.026938  NON-STAT   -0.0293358
# FUTY vs XLU:NON-STAT      ...       -0.054461  NON-STAT   -0.0305864
# FXY vs YCL:STAT           ...       -0.073268      STAT      3.16868
# VPU vs XLU:NON-STAT       ...       -0.058446  NON-STAT   -0.0250067
# GLD vs PHYS:STAT          ...       -0.128599      STAT   -0.0999658
# SCHG vs VOOG:STAT         ...       -0.044883      STAT   -0.0440855
# SCHB vs VONE:NON-STAT     ...       -0.022951  NON-STAT   -0.0190336
# PGF vs PGX:STAT           ...       -0.013941      STAT  -0.00897249
# DOG vs DXD:STAT           ...       -0.258011      STAT    -0.269622
# SBND vs TTT:STAT          ...       -0.316111      STAT    -0.383532
# DNO vs DTO:NON-STAT       ...       -0.178458  NON-STAT     0.560653
# ITOT vs VOO:STAT          ...       -0.104673      STAT   -0.0748842
# IWB vs SCHB:NON-STAT      ...       -0.030320  NON-STAT   -0.0316657
# SSO vs VOO:STAT           ...       -0.085778      STAT     0.300069
# IWL vs MGC:STAT           ...       -0.045001      STAT    -0.693932
# TBT vs TMV:NON-STAT       ...       -0.176300  NON-STAT      -0.1121
# ...                       ...             ...       ...          ...
# EMES vs EMESQ:STAT        ...        0.000000      STAT            0
# EMES vs EMESZ:STAT        ...        0.000000      STAT            0
# PHIO vs RXII:STAT         ...       -0.441320      STAT    -0.555709
# PTIE vs SAVA:STAT         ...        0.000000      STAT            0
# RAS vs RASFD:STAT         ...        0.000000      STAT            0
# CBS vs VIAC:NON-STAT      ...       -0.001104  NON-STAT  -0.00364754
# CHI_2 vs QQQC:STAT        ...       -0.136631      STAT    -0.414362
# CUR vs SNCA:STAT          ...        0.000000      STAT            0
# CWEN vs NYLD:STAT         ...       -0.032732      STAT    0.0045342
# EVLV vs IMBI:STAT         ...       -0.786618      STAT       47.877
# IPCI vs IPCIF:STAT        ...       -0.000537      STAT  -0.00126178
# KEG vs KEGX:STAT          ...       -0.001466      STAT  -0.00146606
# KEG vs KEGXD:STAT         ...       -0.001466      STAT  -0.00146606
# MPVD vs MPVDF:STAT        ...       -0.093904      STAT    -0.171946
# PIPR vs PJC:STAT          ...       -0.005158      STAT  -0.00267536
# SDRL vs SDRL_:STAT        ...       -4.274480      STAT     -7.51087
# SPN vs SPNV:STAT          ...       -0.251225      STAT     0.045222
# SPN vs SPNVD:STAT         ...       -0.251225      STAT     0.045222
# TTS vs TTSH:STAT          ...        0.000000      STAT   -0.0214337
# ANW vs ANWWQ:STAT         ...        0.000000      STAT            0
# ATCO vs SSW:STAT          ...        0.000000      STAT            0
# BAS vs BASX:STAT          ...        0.000000      STAT -0.000431231
# FEU vs SPEU:STAT          ...       -0.002116      STAT  -0.00361334
# FRGA vs TAX:STAT          ...        0.000000      STAT            0
# GOV vs OPI:STAT           ...       -0.143663      STAT    -0.110121
# HPT vs SVC:STAT           ...       -0.000938      STAT   -0.0083456
# OZM vs SCU:NON-STAT       ...       -0.033863  NON-STAT   -0.0371318
# PXMV vs XMVM:STAT         ...       -0.000949      STAT   -0.0131698
# RC vs SLD:STAT            ...       -0.002574      STAT    -0.174087
# TAX vs TAXA:STAT          ...        0.000000      STAT            0
#
#                            pct_0.5     pct_0.75        pct_1     pct_1.25  \
# MZZ vs SMDD:NON-STAT     -0.536546    -0.527464    -0.649391      0.11836
# EDV vs UBT:NON-STAT      -0.104118    -0.104118    -0.120034    -0.120034
# IVV vs IWB:STAT         -0.0700966    -0.061614    -0.050783   -0.0663766
# DGL vs SGOL:STAT        0.00334176  -0.00901351   -0.0129883   -0.0359514
# PHDG vs VQT:STAT        -0.0404177   -0.0134699   -0.0272402   -0.0366144
# IWV vs SCHB:NON-STAT     0.0633046    0.0743174    0.0771788    0.0798677
# IWB vs SPY:STAT         -0.0648368   -0.0550465   -0.0402545   -0.0501556
# IWB vs SSO:STAT           0.553848     0.553848     0.553848     0.552849
# CURE vs RXL:STAT           -1.1185    -0.125465    -0.147376     -0.13619
# EUSA vs VV:STAT           0.340551     0.435214     0.666739    0.0180632
# PHYS vs SGOL:NON-STAT   -0.0158119   -0.0128189   -0.0107773  -0.00752138
# FXP vs YANG:NON-STAT      0.467665     0.712726      0.71826     0.672006
# SCHB vs VTI:NON-STAT     0.0534524    0.0684743    0.0640686    0.0569592
# DGL vs GLD:STAT          0.0555277    0.0492229    0.0492229    0.0485734
# DLN vs VYM:NON-STAT      -0.027121    -0.022886   -0.0224654   -0.0220874
# FUTY vs XLU:NON-STAT    -0.0431421   -0.0479024   -0.0345429   -0.0437302
# FXY vs YCL:STAT            5.26144     -2.44909    -0.376127    -0.382583
# VPU vs XLU:NON-STAT     -0.0525548    -0.029146   -0.0371549   -0.0372283
# GLD vs PHYS:STAT         -0.112673  0.000247124   -0.0583157    -0.129584
# SCHG vs VOOG:STAT       -0.0440347   -0.0277454   -0.0180349   -0.0204131
# SCHB vs VONE:NON-STAT   -0.0218487    0.0151505    0.0031955   -0.0191212
# PGF vs PGX:STAT        -0.00838054    -0.011138  -0.00936441  -0.00936645
# DOG vs DXD:STAT          -0.222511    -0.219855    -0.263118    -0.203716
# SBND vs TTT:STAT         -0.387219     -0.27943    -0.268174    -0.212566
# DNO vs DTO:NON-STAT       0.688029     0.688029     0.688029     0.688029
# ITOT vs VOO:STAT        -0.0853944     -0.07931   -0.0654869   -0.0626184
# IWB vs SCHB:NON-STAT    -0.0337256   -0.0190763 -0.000486666   -0.0121102
# SSO vs VOO:STAT           0.301758     0.299022     0.299022     0.299022
# IWL vs MGC:STAT        -0.00534454   -0.0623082   -0.0363262   -0.0365554
# TBT vs TMV:NON-STAT      -0.137659     -0.16806    -0.153583    -0.189023
# ...                            ...          ...          ...          ...
# EMES vs EMESQ:STAT               0            0            0            0
# EMES vs EMESZ:STAT               0            0            0            0
# PHIO vs RXII:STAT        -0.555709    -0.555709    -0.555709    -0.555709
# PTIE vs SAVA:STAT                0            0            0            0
# RAS vs RASFD:STAT                0            0            0            0
# CBS vs VIAC:NON-STAT   -0.00356303  -0.00354912  -0.00344785  -0.00337776
# CHI_2 vs QQQC:STAT       0.0844839     0.239201    -0.116368    0.0799085
# CUR vs SNCA:STAT                 0            0            0            0
# CWEN vs NYLD:STAT        0.0045342   0.00550981   0.00545915   0.00612224
# EVLV vs IMBI:STAT          41.6273     0.871977     0.871977      0.87727
# IPCI vs IPCIF:STAT    -0.000536773 -0.000536773 -0.000536773 -0.000536773
# KEG vs KEGX:STAT       -0.00146606  -0.00146606  -0.00146606  -0.00146606
# KEG vs KEGXD:STAT      -0.00146606  -0.00146606  -0.00146606  -0.00146606
# MPVD vs MPVDF:STAT       -0.171946    -0.171946    -0.171946    -0.171946
# PIPR vs PJC:STAT       -0.00363962   -0.0034096  -0.00420276  -0.00559609
# SDRL vs SDRL_:STAT        -7.51087     -7.51087     -7.51087     -7.51087
# SPN vs SPNV:STAT          0.045222     0.045222     0.045222     0.045222
# SPN vs SPNVD:STAT         0.045222     0.045222     0.045222     0.045222
# TTS vs TTSH:STAT        -0.0176083   -0.0137882   -0.0100703   -0.0114615
# ANW vs ANWWQ:STAT                0            0            0            0
# ATCO vs SSW:STAT                 0            0            0            0
# BAS vs BASX:STAT                 0            0            0            0
# FEU vs SPEU:STAT       -0.00250949  -0.00245289  -0.00240074  -0.00227069
# FRGA vs TAX:STAT                 0            0            0            0
# GOV vs OPI:STAT          -0.110121    -0.110121    -0.110121   -0.0844353
# HPT vs SVC:STAT        -0.00373532  -0.00362989  -0.00362912   -0.0012123
# OZM vs SCU:NON-STAT     -0.0369711   -0.0359398   -0.0357692   -0.0357519
# PXMV vs XMVM:STAT       -0.0114359   -0.0114359  -0.00915717  -0.00642255
# RC vs SLD:STAT          0.00982002  0.000542523   0.00171997   0.00490289
# TAX vs TAXA:STAT                 0            0            0            0
#
#                            pct_1.5     pct_1.75        pct_2
# MZZ vs SMDD:NON-STAT       0.11836      1.00919      1.00919
# EDV vs UBT:NON-STAT      -0.120034     -0.12054    -0.118858
# IVV vs IWB:STAT         -0.0429055   -0.0206542   -0.0221213
# DGL vs SGOL:STAT        -0.0344774   -0.0390389   -0.0169687
# PHDG vs VQT:STAT        -0.0347996   -0.0314935   -0.0130582
# IWV vs SCHB:NON-STAT     0.0844044    0.0271378    0.0303951
# IWB vs SPY:STAT         -0.0260362  -0.00516893  -0.00483275
# IWB vs SSO:STAT           0.552857     0.552912     0.550319
# CURE vs RXL:STAT         -0.113004   -0.0944052   -0.0958358
# EUSA vs VV:STAT          -0.134706    -0.141772    -0.152368
# PHYS vs SGOL:NON-STAT   -0.0121717   -0.0126858  -0.00472686
# FXP vs YANG:NON-STAT       0.72291     0.682564     0.724572
# SCHB vs VTI:NON-STAT     0.0611052    0.0322265    0.0319102
# DGL vs GLD:STAT          0.0485734    0.0620927    0.0587703
# DLN vs VYM:NON-STAT     -0.0229153   -0.0229004   -0.0244377
# FUTY vs XLU:NON-STAT    -0.0410862   -0.0447678   -0.0447678
# FXY vs YCL:STAT          -0.144694   -0.0752302   -0.0349611
# VPU vs XLU:NON-STAT     -0.0306671   -0.0341335   -0.0274021
# GLD vs PHYS:STAT         -0.129653     -0.10731     -0.10987
# SCHG vs VOOG:STAT       -0.0171206   -0.0174187   -0.0213474
# SCHB vs VONE:NON-STAT   -0.0149793   0.00983738    0.0117788
# PGF vs PGX:STAT         -0.0113924   -0.0118396   -0.0117283
# DOG vs DXD:STAT          -0.220115    -0.214473    -0.240863
# SBND vs TTT:STAT         -0.256882      -0.2143    -0.186089
# DNO vs DTO:NON-STAT       0.400634     0.280278     0.321211
# ITOT vs VOO:STAT        -0.0657492   -0.0426986   -0.0210461
# IWB vs SCHB:NON-STAT     -0.010411   -0.0173651   -0.0155236
# SSO vs VOO:STAT           0.311519     0.311519     0.311519
# IWL vs MGC:STAT         -0.0430096   -0.0291501   -0.0290549
# TBT vs TMV:NON-STAT      -0.181581    -0.149126    -0.163983
# ...                            ...          ...          ...
# EMES vs EMESQ:STAT               0            0            0
# EMES vs EMESZ:STAT               0            0            0
# PHIO vs RXII:STAT        -0.514154     -0.47968    -0.111519
# PTIE vs SAVA:STAT                0            0            0
# RAS vs RASFD:STAT                0            0            0
# CBS vs VIAC:NON-STAT   -0.00122515  -0.00118424  -0.00110435
# CHI_2 vs QQQC:STAT      -0.0655965    0.0379492   -0.0744037
# CUR vs SNCA:STAT                 0            0            0
# CWEN vs NYLD:STAT       0.00501641   0.00630363   -0.0150492
# EVLV vs IMBI:STAT        -0.543317    -0.543317    -0.543317
# IPCI vs IPCIF:STAT    -0.000536773 -0.000536773 -0.000536773
# KEG vs KEGX:STAT       -0.00146606  -0.00146606  -0.00146606
# KEG vs KEGXD:STAT      -0.00146606  -0.00146606  -0.00146606
# MPVD vs MPVDF:STAT       -0.171946    -0.221742     0.121828
# PIPR vs PJC:STAT      -0.000839415   -0.0020082  -0.00378367
# SDRL vs SDRL_:STAT        -7.51087     -7.51087     -7.51087
# SPN vs SPNV:STAT          0.045222     0.045222     0.045222
# SPN vs SPNVD:STAT         0.045222     0.045222     0.045222
# TTS vs TTSH:STAT        -0.0132953   -0.0158129            0
# ANW vs ANWWQ:STAT                0            0            0
# ATCO vs SSW:STAT                 0            0            0
# BAS vs BASX:STAT                 0            0            0
# FEU vs SPEU:STAT         -0.002227  -0.00220097  -0.00210101
# FRGA vs TAX:STAT                 0            0            0
# GOV vs OPI:STAT         -0.0853002   -0.0853002   -0.0853002
# HPT vs SVC:STAT        -0.00106933 -0.000999085 -0.000921872
# OZM vs SCU:NON-STAT     -0.0358232   -0.0338896    -0.033863
# PXMV vs XMVM:STAT     -0.000867159 -0.000908524 -0.000908524
# RC vs SLD:STAT          0.00522533   0.00820995   0.00476346
# TAX vs TAXA:STAT                 0            0            0
#
# [239 rows x 49 columns]

# %%
pnl_data_1 = pd.DataFrame()
pnl_data_2 = pd.DataFrame()
pnl_data_3 = pd.DataFrame()
pnl_data_4 = pd.DataFrame()
pnl_data_5 = pd.DataFrame()
pnl_data_6 = pd.DataFrame()
pnl_data_7 = pd.DataFrame()
pnl_data_8 = pd.DataFrame()
tickers = list(data.index)

def get_pnl(band, dbase, band_base):
    d = pd.read_csv(file_main_data + 'pair_sim_band_' + str(band) + '.csv')
    dg = d.groupby('symbol')
    tickers = list(data.index)
    for i in range(len(dbase)):
        band_base[tickers[i]] = dg.get_group(tickers[i]).pnl.reset_index(drop=True)
    return band_base

def get_pnl_list(pnl_data, band):
    list_of_pnl = []
    for i in range(len(coint_pairs)):
        tick = pd.DataFrame()
        tick['data'] = pnl_data[tickers[i]]
        tick['pos'] = pnl_data[tickers[i]] > 0

        t = tick.groupby('pos').get_group(False)
        try:
            tt = tick.groupby('pos').get_group(True)
        except KeyError:
            pass

        t_len = len(t)
        tt_len = len(tt)

        t_mean = t['data'].mean()
        tt_mean = tt['data'].mean()

        whole_avg = pnl_data[tickers[i]].mean()

        r = (tickers[i], t_len, tt_len, t_mean, tt_mean, whole_avg, data['perf_'+str(band)].iloc[i])
        list_of_pnl.append(r)

    return list_of_pnl        


def make_df_pnl(pnl_list, band):
    df = pd.DataFrame(data=pnl_list, columns=['pair', 'no_loss', 'no_win', 'avg_loss', 'avg_win', 'whole_avg', 'perf_'+str(band)])
    df.set_index('pair', inplace=True)
    s = list(df.index)
    df['stat'] = [s[i].split(':')[1] for i in range(len(s))]
    df['pos_avg'] = df.whole_avg > 0
    df['win'] = df['perf_'+ str(band)] > 100000
    tot_days = df['no_loss'] + df['no_win']
    df['loss_percent'] = round(df['no_loss']/tot_days, 2)
    df['win_percent'] = round(df['no_win']/tot_days, 2)
    
    
    return df[df['perf_'+str(band)] != 100000]


pnl_1 = get_pnl(0.25, data, pnl_data_1)
pnl_2 = get_pnl(0.5,  data, pnl_data_2)
pnl_3 = get_pnl(0.75, data, pnl_data_3)
pnl_4 = get_pnl(1,  data, pnl_data_4)
pnl_5 = get_pnl(1.25, data, pnl_data_5)
pnl_6 = get_pnl(1.5,  data, pnl_data_6)
pnl_7 = get_pnl(1.75, data, pnl_data_7)
pnl_8 = get_pnl(2,  data, pnl_data_8)


list_1 = get_pnl_list(pnl_1, 0.25)
list_2 = get_pnl_list(pnl_2, 0.5)
list_3 = get_pnl_list(pnl_3, 0.75)
list_4 = get_pnl_list(pnl_4, 1)
list_5 = get_pnl_list(pnl_5, 1.25)
list_6 = get_pnl_list(pnl_6, 1.5)
list_7 = get_pnl_list(pnl_7, 1.75)
list_8 = get_pnl_list(pnl_8, 2)


df_1 = make_df_pnl(list_1, 0.25)
df_2 = make_df_pnl(list_2, 0.5)
df_3 = make_df_pnl(list_3, 0.75)
df_4 = make_df_pnl(list_4, 1)
df_5 = make_df_pnl(list_5, 1.25)
df_6 = make_df_pnl(list_6, 1.5)
df_7 = make_df_pnl(list_7, 1.75)
df_8 = make_df_pnl(list_8, 2)



def get_tables(data, band):
    
    cols = ['no_loss', 'no_win', 'avg_loss','avg_win', 'whole_avg', 'perf_' + str(band), 'loss_percent', 'win_percent']
    
    avg_list = [list(round(data[cols].mean(), 2).reset_index(drop=True))[i] for i in range(8)]
    
    stat_list = list(round(data.groupby('stat').get_group('STAT')[cols].mean(), 2))
    
    nstat_list = list(round(data.groupby('stat').get_group('NON-STAT')[cols].mean(), 2))
    
    stat = data.groupby('stat').get_group('STAT')
    
    win_stat = list(round(stat.groupby('win').get_group(True)[cols].mean(), 2))
    
    nstat = data.groupby('stat').get_group('NON-STAT')
    
    win_nstat = list(round(nstat.groupby('win').get_group(True)[cols].mean(), 2))
    
    df_list = [avg_list, stat_list, nstat_list, win_stat, win_nstat]
    
    index = ['avg', 'avg stat', 'avg non-stat', 'avg winning stat', 'avg winning non-stat']
    
    list_to_df =  pd.DataFrame(data=df_list, columns=cols, index=index)
    list_to_df.to_latex(buf=file_data + str(band)+' daily returns band.txt', index=True)
    print(list_to_df)
    

get_tables(df_1, 0.25)
get_tables(df_2, 0.5)
get_tables(df_3, 0.75)
get_tables(df_4, 1)
get_tables(df_5, 1.25)
get_tables(df_6, 1.5)
get_tables(df_7, 1.75)
get_tables(df_8, 2)
# Out:
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    150.76  104.10  -2915.35  4506.94     -63.74
# avg stat               151.98  103.40  -3517.02  5824.08     -43.44
# avg non-stat           148.03  105.66  -1573.94  1570.35    -108.98
# avg winning stat       137.81  114.19  -7081.06  9407.87     845.42
# avg winning non-stat   127.45  124.55  -1881.84  2453.71     318.43
#
#                       perf_0.25  loss_percent  win_percent
# avg                    83938.72          0.59         0.41
# avg stat               89052.22          0.59         0.41
# avg non-stat           72538.15          0.58         0.42
# avg winning stat      313046.56          0.55         0.45
# avg winning non-stat  180244.39          0.51         0.49
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    151.39  102.96  -2367.08  3734.48    -115.74
# avg stat               151.92  102.74  -2749.69  4669.95    -147.46
# avg non-stat           150.25  103.43  -1532.86  1694.85     -46.60
# avg winning stat       144.39  107.61  -3487.79  5423.95     719.39
# avg winning non-stat   128.36  123.64   -978.34  1422.05     156.63
#
#                        perf_0.5  loss_percent  win_percent
# avg                    70832.66          0.59         0.41
# avg stat               62840.79          0.60         0.40
# avg non-stat           88257.55          0.59         0.41
# avg winning stat      281285.88          0.57         0.43
# avg winning non-stat  139471.03          0.51         0.49
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    152.90  101.10  -2512.14  2608.62    -183.27
# avg stat               153.35  100.80  -2975.25  3028.87    -251.06
# avg non-stat           151.92  101.75  -1517.60  1706.12     -37.69
# avg winning stat       143.00  109.00  -1783.99  2315.41     114.67
# avg winning non-stat   130.21  121.79   -898.09  1308.03     145.44
#
#                       perf_0.75  loss_percent  win_percent
# avg                    53815.48          0.60         0.40
# avg stat               36732.55          0.60         0.40
# avg non-stat           90501.77          0.60         0.40
# avg winning stat      128895.77          0.57         0.43
# avg winning non-stat  136650.41          0.52         0.48
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    156.69   97.31  -1819.75  1837.09    -174.30
# avg stat               157.73   96.42  -1995.26  1903.30    -246.31
# avg non-stat           154.44   99.23  -1442.85  1694.90     -19.66
# avg winning stat       151.00  101.00   -833.66  1368.36     119.98
# avg winning non-stat   131.54  120.46   -941.59  1383.64     153.55
#
#                          perf_1  loss_percent  win_percent
# avg                    56075.79          0.62         0.38
# avg stat               37929.77          0.62         0.38
# avg non-stat           95045.11          0.61         0.39
# avg winning stat      130234.95          0.60         0.40
# avg winning non-stat  138695.78          0.52         0.48
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    158.71   95.30  -1729.85  1754.20    -179.96
# avg stat               158.90   95.26  -1981.87  1848.86    -259.73
# avg non-stat           158.30   95.38  -1209.28  1558.68     -15.20
# avg winning stat       148.04  103.96   -585.01   953.12      93.81
# avg winning non-stat   133.92  118.08  -4575.16  5973.93     168.03
#
#                       perf_1.25  loss_percent  win_percent
# avg                    54648.99          0.62         0.38
# avg stat               34548.06          0.62         0.38
# avg non-stat           96168.93          0.62         0.38
# avg winning stat      123640.77          0.59         0.41
# avg winning non-stat  142344.52          0.53         0.47
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    163.14   91.10  -1845.90  1884.45    -183.33
# avg stat               162.63   91.87  -2163.64  2044.93    -264.00
# avg non-stat           164.18   89.52  -1189.60  1552.97     -16.71
# avg winning stat       152.92   99.08  -1512.78  1944.54      99.76
# avg winning non-stat   144.12  107.88  -3276.58  4278.01     113.95
#
#                        perf_1.5  loss_percent  win_percent
# avg                    53801.13          0.64         0.36
# avg stat               33473.02          0.64         0.36
# avg non-stat           95790.33          0.65         0.35
# avg winning stat      125140.14          0.61         0.39
# avg winning non-stat  128714.96          0.57         0.43
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    167.55   86.69  -2279.85  2401.65    -224.17
# avg stat               165.98   88.54  -2893.41  2889.55    -329.61
# avg non-stat           170.77   82.92  -1022.54  1401.87      -8.10
# avg winning stat       158.08   93.92  -1372.83  2089.46      86.06
# avg winning non-stat   149.06  102.94  -2741.23  3715.78     128.77
#
#                       perf_1.75  loss_percent  win_percent
# avg                    43509.74          0.66         0.34
# avg stat               16938.88          0.65         0.35
# avg non-stat           97958.23          0.67         0.33
# avg winning stat      121686.49          0.63         0.37
# avg winning non-stat  132449.36          0.59         0.41
#                       no_loss  no_win  avg_loss  avg_win  whole_avg  \
# avg                    172.65   81.63  -2198.39  2303.96    -201.18
# avg stat               170.77   83.77  -2771.85  2729.84    -294.88
# avg non-stat           176.52   77.22  -1013.23  1423.80      -7.55
# avg winning stat       158.78   93.22  -1061.79  1632.31     104.09
# avg winning non-stat   152.06   99.94  -2734.01  3728.52     127.30
#
#                          perf_2  loss_percent  win_percent
# avg                    49301.71          0.68         0.32
# avg stat               25691.35          0.67         0.33
# avg non-stat           98096.46          0.70         0.30
# avg winning stat      126231.14          0.63         0.37
# avg winning non-stat  132078.83          0.60         0.40

# %%
data = data[data['perf_0.25'] != 100000]

# %%
for band in bands:
    
    def get_beta(band, dbase):
        d = pd.read_csv(file_main_data + 'pair_sim_band_' + str(band) + '.csv')
        dg = d.groupby('symbol')
        betas = []
        tickers = list(dbase.index)
        for i in range(len(dbase)):
            betas.append(dg.get_group(tickers[i]).beta.iloc[-1])

        return betas
    
    def get_alpha(band, dbase):
        d = pd.read_csv(file_main_data + 'pair_sim_band_' + str(band) + '.csv')
        dg = d.groupby('symbol')
        alphas = []
        tickers = list(dbase.index)
        for i in range(len(dbase)):
            alphas.append(dg.get_group(tickers[i]).alpha.iloc[-1])

        return alphas
    
    def get_sharpe(band, dbase):
        d = pd.read_csv(file_main_data + 'pair_sim_band_' + str(band) + '.csv')
        dg = d.groupby('symbol')
        sharpes = []
        tickers = list(dbase.index)
        for i in range(len(dbase)):
            sharpes.append(dg.get_group(tickers[i]).sharpe.iloc[-1])

        return sharpes
    
    def get_maxdraw(year, dbase):
        d = pd.read_csv(file_main_data + 'pair_sim_band_' + str(band) + '.csv')
        dg = d.groupby('symbol')
        maxes = []
        tickers = list(dbase.index)
        for i in range(len(dbase)):
            maxes.append(dg.get_group(tickers[i]).max_drawdown.iloc[-1])
        return maxes

    data['beta_'+str(band)] = get_beta(band, data)
    data['alpha_'+str(band)] = get_alpha(band, data)
    data['sharpe_'+str(band)] = get_sharpe(band, data)
    data['maxdraw_'+str(band)] = get_maxdraw(band, data)
# Out:
# /opt/anaconda3/envs/zipline/lib/python3.5/site-packages/ipykernel/__main__.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda3/envs/zipline/lib/python3.5/site-packages/ipykernel/__main__.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda3/envs/zipline/lib/python3.5/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda3/envs/zipline/lib/python3.5/site-packages/ipykernel/__main__.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data

# %%
data_group = data.groupby('STAT')
stat_data = data_group.get_group('STAT')
nstat_data = data_group.get_group('NON-STAT')
print('the number of stats: {}'.format(len(stat_data)))
print('the number of nstats: {}'.format(len(nstat_data)))

# %%
### GETTING AVERAGE RESULTS ###
average_perf = OrderedDict()
pct_mean = OrderedDict()
pct_std = OrderedDict()
alpha_mean = OrderedDict()
beta_mean = OrderedDict()
sharpe_mean = OrderedDict()
maxdraw_mean= OrderedDict()

best_20_perf = OrderedDict()
worst_20_perf = OrderedDict()

data_len = len(data)

for band in bands:
    average_perf[band] = round(data['perf_' + str(band)].mean(),2)
    pct_mean[band] = round(data['pct_' + str(band)].mean(), 2)
    pct_std[band] = round(data['pct_'+str(band)].std(), 2)
    alpha_mean[band] = round(data['alpha_' + str(band)].mean(), 2)
    beta_mean[band] = round(data['beta_' + str(band)].mean(), 2)
    sharpe_mean[band] = round(data['sharpe_' + str(band)].mean(), 2)
    maxdraw_mean[band] = round(data['maxdraw_'+str(band)].mean(), 2)
    
    d = pd.read_csv(file_data + '/pair_sim_band_' + str(band)+'.csv')
    best_idx = [data['perf_'+str(band)].sort_values()[data_len-20:data_len].index[i] for i in range(20)]
    worst_idx = [data['perf_'+str(band)].sort_values()[:20].index[i] for i in range(20)]
    
    best_20_perf[band] = [(best_idx[i], d[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_perf[band] = [(worst_idx[i], d[worst_idx[i]]) for i in range(len(worst_idx))]

colnames = ['average portfolio value', 'average percentage change', 'average standard deviation',
            'average alpha', 'average beta', 'average sharpe ratio', 'average max drawdown']

list_of_dicts = [average_perf, pct_mean, pct_std,
                 alpha_mean, beta_mean, sharpe_mean, maxdraw_mean ]

main_df = pd.DataFrame()
main_df['band'] = pd.Series(bands)

for i in range(len(list_of_dicts)):
    df = pd.DataFrame(data=list(list_of_dicts[i].items()) , columns=['band', colnames[i]] )
    main_df = pd.concat([main_df, df[colnames[i]]], axis=1)
main_df.to_latex(buf=file_data+'average-perf.txt', index=False)

# %%
### GETTING STAT AVERAGE RESULTS ### 
stat_average_perf = OrderedDict()
stat_pct_mean = OrderedDict()
stat_pct_std = OrderedDict()
stat_alpha_mean = OrderedDict()
stat_beta_mean = OrderedDict()
stat_sharpe_mean = OrderedDict()
stat_maxdraw_mean = OrderedDict()

best_20_perf_stat = OrderedDict()
worst_20_perf_stat = OrderedDict()

best_20_alpha_stat = OrderedDict()
best_20_beta_stat = OrderedDict()
best_20_sharpe_stat = OrderedDict()
best_20_maxdraw_stat = OrderedDict()

worst_20_alpha_stat = OrderedDict()
worst_20_beta_stat = OrderedDict()
worst_20_sharpe_stat = OrderedDict()
worst_20_maxdraw_stat = OrderedDict()

data_len_stat = len(stat_data)

for band in bands:
    stat_average_perf[band] = round(stat_data['perf_' + str(band)].mean(), 2)
    stat_pct_mean[band] = round(stat_data['pct_' + str(band)].mean(), 2)
    stat_pct_std[band] = round(stat_data['pct_'+str(band)].std(), 2)
    stat_alpha_mean[band] = round(stat_data['alpha_' + str(band)].mean(), 2)
    stat_beta_mean[band] = round(stat_data['beta_' + str(band)].mean(), 2)
    stat_sharpe_mean[band] = round(stat_data['sharpe_' + str(band)].mean(), 2)
    stat_maxdraw_mean[band] = round(stat_data['maxdraw_'+str(band)].mean(), 2)
    
    d = pd.read_csv(file_data + '/pair_sim_band_' + str(band)+'.csv')
    best_idx = [stat_data['perf_'+str(band)].sort_values()[data_len_stat-20:data_len_stat].index[i] for i in range(20)]
    worst_idx = [stat_data['perf_'+str(band)].sort_values()[:20].index[i] for i in range(20)]
    
    best_20_perf_stat[band] = [(best_idx[i], d[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_perf_stat[band] = [(worst_idx[i], d[worst_idx[i]]) for i in range(len(worst_idx))]
    
    best_20_alpha_stat[band] = [(best_idx[i], stat_data['alpha_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_alpha_stat[band] = [(worst_idx[i], stat_data['alpha_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]
    
    best_20_beta_stat[band] = [(best_idx[i], stat_data['beta_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_beta_stat[band] = [(worst_idx[i], stat_data['beta_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]

    best_20_sharpe_stat[band] = [(best_idx[i], stat_data['sharpe_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_sharpe_stat[band] = [(worst_idx[i], stat_data['sharpe_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]
 
    best_20_maxdraw_stat[band] = [(best_idx[i], stat_data['maxdraw_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_maxdraw_stat[band] = [(worst_idx[i], stat_data['maxdraw_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]
    
colnames = ['average portfolio value', 'average percentage change', 'average standard deviation',
            'average alpha', 'average beta', 'average sharpe ratio', 'average max drawdown']

list_of_dicts = [stat_average_perf,stat_pct_mean, stat_pct_std,
                 stat_alpha_mean, stat_beta_mean,stat_sharpe_mean, stat_maxdraw_mean ]

main_df = pd.DataFrame()
main_df['band'] = pd.Series(bands)

for i in range(len(list_of_dicts)):
    df = pd.DataFrame(data=list(list_of_dicts[i].items()) , columns=['band', colnames[i]] )
    main_df = pd.concat([main_df, df[colnames[i]]], axis=1)
main_df.to_latex(buf=file_data+'stat-perf-bands.txt', index=False)


for band in bands:
    fig, ax = plt.subplots(figsize = (30, 30))
    ax.set_ylabel("Protfolio Value, $'s")
    ax.set_xlabel('days')
    plt.axhline(100000, color='red', ls='--', label='Initial capital')
    plt.title('The Best 20 performing stat pairs, using band: {}'.format(band))
    
    for i in range(len(best_20_perf_stat[band])):
        ax.plot(best_20_perf_stat[band][i][1])
    plt.legend(loc='best')
    plt.savefig(fname=file_data + '/PLOTS/STAT/best_20_stat_band_' + str(band) + '.png')
    plt.show()
    
    fig1, ax1 = plt.subplots(figsize = (30, 30))
    ax1.set_ylabel("Protfolio Value, $'s")
    ax1.set_xlabel('days')
    plt.axhline(100000, color='red', ls='--', label='Initial capital')    
    for i in range(len(worst_20_perf_stat[band])):
        ax1.plot(worst_20_perf_stat[band][i][1])
        plt.title('The Worst 20 performing stat pairs, using a moving window: {}'.format(band))
    plt.legend(loc='best')
    plt.savefig(fname=file_data + 'PLOTS/STAT/worst_20_stat_band_' + str(band) + '.png')
    plt.show()

# %%
### GETTING NON-STAT AVERAGE RESULTS ### 
nstat_average_perf = OrderedDict()
nstat_pct_mean = OrderedDict()
nstat_pct_std = OrderedDict()
nstat_alpha_mean = OrderedDict()
nstat_beta_mean = OrderedDict()
nstat_sharpe_mean = OrderedDict()
nstat_maxdraw_mean = OrderedDict()

best_20_perf_nstat = OrderedDict()
worst_20_perf_nstat = OrderedDict()

best_20_alpha_nstat = OrderedDict()
best_20_beta_nstat = OrderedDict()
best_20_sharpe_nstat = OrderedDict()
best_20_maxdraw_nstat = OrderedDict()

worst_20_alpha_nstat = OrderedDict()
worst_20_beta_nstat = OrderedDict()
worst_20_sharpe_nstat = OrderedDict()
worst_20_maxdraw_nstat = OrderedDict()

data_len_nstat = len(nstat_data)

for band in bands:
    nstat_average_perf[band] = round(nstat_data['perf_' + str(band)].mean(), 2)
    nstat_pct_mean[str(band)] = round(nstat_data['pct_' + str(band)].mean(), 2)
    nstat_pct_std[band] = round(nstat_data['pct_'+str(band)].std(), 2)
    nstat_alpha_mean[band] = round(nstat_data['alpha_' + str(band)].mean(), 2)
    nstat_beta_mean[band] = round(nstat_data['beta_' + str(band)].mean(), 2)
    nstat_sharpe_mean[band] = round(nstat_data['sharpe_' + str(band)].mean(), 2)
    nstat_maxdraw_mean[band] = round(nstat_data['maxdraw_'+str(band)].mean(), 2)
    
    d = pd.read_csv(file_data + '/pair_sim_band_' + str(band)+'.csv')
    best_idx = [nstat_data['perf_'+str(band)].sort_values()[data_len_nstat-20:data_len_nstat].index[i] for i in range(20)]
    worst_idx = [nstat_data['perf_'+str(band)].sort_values()[:20].index[i] for i in range(20)]
    
    best_20_perf_nstat[band] = [(best_idx[i], d[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_perf_nstat[band] = [(worst_idx[i], d[worst_idx[i]]) for i in range(len(worst_idx))]
    
    best_20_alpha_nstat[band] = [(best_idx[i], nstat_data['alpha_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_alpha_nstat[band] = [(worst_idx[i], nstat_data['alpha_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]
    
    best_20_beta_nstat[band] = [(best_idx[i], nstat_data['beta_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_beta_nstat[band] = [(worst_idx[i], nstat_data['beta_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]

    best_20_sharpe_nstat[band] = [(best_idx[i], nstat_data['sharpe_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_sharpe_nstat[band] = [(worst_idx[i], nstat_data['sharpe_' + str(band)].loc[worst_idx[i]]) for i in range(len(worst_idx))]
    
    best_20_maxdraw_nstat[band] = [(best_idx[i], nstat_data['maxdraw_' + str(band)].loc[best_idx[i]]) for i in range(len(best_idx))]
    worst_20_maxdraw_nstat[band] = [(worst_idx[i], nstat_data['maxdraw_' + str(band)].loc[best_idx[i]]) for i in range(len(worst_idx))]
    
#### AVERAGE NON-STAT
colnames = ['average portfolio value', 'average percentage change', 'average standard deviation',
            'average alpha', 'average beta', 'average sharpe ratio', 'average max drawdown']

list_of_dicts = [nstat_average_perf,nstat_pct_mean, nstat_pct_std,
                 nstat_alpha_mean, nstat_beta_mean,nstat_sharpe_mean, nstat_maxdraw_mean ]

main_df = pd.DataFrame()
main_df['band'] = pd.Series(bands)

for i in range(len(list_of_dicts)):
    df = pd.DataFrame(data=list(list_of_dicts[i].items()) , columns=['band', colnames[i]] )
    main_df = pd.concat([main_df, df[colnames[i]]], axis=1)
main_df.to_latex(buf=file_data+'non-stat-perf-bands.txt', index=False)



for band in bands:
    fig, ax = plt.subplots(figsize = (30, 30))
    ax.set_ylabel("Protfolio Value, $'s")
    ax.set_xlabel('days')
    plt.axhline(100000, color='red', ls='--', label='Initial capital')
    plt.title('The Best 20 performing non-stat pairs, using band: {}'.format(band))
    
    for i in range(len(best_20_perf_nstat[band])):
        ax.plot(best_20_perf_nstat[band][i][1])
    plt.legend(loc='best')
    plt.savefig(fname=file_data + '/PLOTS/NON-STAT/best_20_nstat_band_' + str(band) + '.png')
    plt.show()
    
    fig1, ax1 = plt.subplots(figsize = (30, 30))
    ax1.set_ylabel("Protfolio Value, $'s")
    ax1.set_xlabel('days')
    plt.axhline(100000, color='red', ls='--', label='Initial capital')    
    
    for i in range(len(worst_20_perf_nstat[band])):
        ax1.plot(worst_20_perf_nstat[band][i][1])
        plt.title('The Worst 20 performing non-stat pairs, using moving window: {}'.format(band))
    plt.legend(loc='best')
    plt.savefig(fname=file_data + 'PLOTS/NON-STAT/worst_20_nstat_band_' + str(band) + '.png')
    plt.show()

# %%
count_aboves_nstat = []
nstat_perf = []
nstat_alpha = []
nstat_beta = []
nstat_sharpe = []
nstat_maxdraw = []

num_of_tradable_pairs = []
for band in bands:
    above = nstat_data[nstat_data['perf_' + str(band)] > 100000]
    nstat_band_best = above[['perf_'+str(band), 'alpha_'+str(band), 'beta_'+str(band),
                         'sharpe_'+str(band), 'maxdraw_'+str(band)]]
    
    nstat_band_best.to_latex(buf=file_data + 'nstat_band_best_' + str(band) + '.txt', index=True)
    
    count_aboves_nstat.append((band, len(above)))
    
    nstat_perf.append( round(above['perf_'+str(band)].mean(),2) )
    nstat_alpha.append( round(above['alpha_'+str(band)].mean(),2) )
    nstat_beta.append( round(above['beta_'+str(band)].mean(),2) )
    nstat_sharpe.append( round(above['sharpe_'+str(band)].mean(), 2) )
    nstat_maxdraw.append( round(above['maxdraw_'+str(band)].mean(),2) )
    print('---- NON-STATONAIRY PAIRS ----')
    print(nstat_band_best)
    
    
    
count_aboves_stat = []
stat_perf = []
stat_alpha = []
stat_beta = []
stat_sharpe = []
stat_maxdraw = []
for band in bands:
    above = stat_data[stat_data['perf_' + str(band)] > 100000]
    stat_band_best = above[['perf_'+str(band), 'alpha_'+str(band), 'beta_'+str(band),
                         'sharpe_'+str(band), 'maxdraw_'+str(band)]]
    stat_band_best.to_latex(buf=file_data + 'stat_band_best_' + str(band) + '.txt', index=True)
    
    count_aboves_stat.append((band, len(above)))
    
    stat_perf.append( round(above['perf_'+str(band)].mean(), 2) )
    stat_alpha.append( round(above['alpha_'+str(band)].mean(),2) )
    stat_beta.append( round(above['beta_'+str(band)].mean(), 2) )
    stat_sharpe.append( round(above['sharpe_'+str(band)].mean(), 2) )
    stat_maxdraw.append( round(above['maxdraw_'+str(band)].mean(), 2) )
    
    print('---- STATIONARY PAIRS ----')
    print(stat_band_best)
    
    
    
count_nstat = pd.DataFrame(data=count_aboves_nstat, columns = ['band', 'count_pos'])
count_nstat['pos %'] = count_nstat.count_pos/len(nstat_data)
count_nstat['avg_perf'] = nstat_perf
count_nstat['avg_alpha'] = nstat_alpha
count_nstat['avg_beta'] = nstat_beta
count_nstat['avg_sharpe'] = nstat_sharpe
count_nstat['avg_maxdraw'] = nstat_maxdraw

count_nstat.to_latex(buf=file_data + 'nstat_count_band.txt', index=False)
print(count_nstat)

count_stat = pd.DataFrame(data=count_aboves_stat, columns = ['band', 'count_pos'])
count_stat['pos %'] = count_stat.count_pos/len(stat_data)
count_stat['avg_perf'] = stat_perf
count_stat['avg_alpha'] = stat_alpha
count_stat['avg_beta'] = stat_beta
count_stat['avg_sharpe'] = stat_sharpe
count_stat['avg_maxdraw'] = stat_maxdraw

count_stat.to_latex(buf=file_data + 'stat_count_band.txt', index=False)
print(count_stat)
